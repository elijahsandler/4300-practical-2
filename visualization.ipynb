# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv('data_collection.csv')
df.tail()
# Out:
#                       timestamp   ram database embedding              llm  \
# 103  2025-04-02T19:41:00.565207  24.0   chroma     mxbai  llama3.2:latest
# 104  2025-04-02T19:41:04.582560  24.0    redis     mxbai   mistral:latest
# 105  2025-04-02T19:41:09.593359  24.0   chroma     mxbai   mistral:latest
# 106  2025-04-02T19:41:14.165902  24.0    redis     mxbai  llama3.2:latest
# 107  2025-04-02T19:41:17.128500  24.0   chroma     mxbai  llama3.2:latest
#
#                                                 prompt  response_time_sec  \
# 103  When are linked lists faster than contiguously...           7.038662
# 104  What does the $nin operator mean in a Mongo qu...           3.969674
# 105  What does the $nin operator mean in a Mongo qu...           4.978713
# 106  What does the $nin operator mean in a Mongo qu...           4.539548
# 107  What does the $nin operator mean in a Mongo qu...           2.915613
#
#      response_length  prompt_length
# 103             1487            271
# ...

# %%
fig = px.scatter(df, x='prompt_length', y='response_time_sec', 
                 color='embedding', symbol='database',
                #  template='plotly_white'
                 )
fig.update_layout(xaxis_title='Prompt Length (characters)',
                  yaxis_title='Response Time (centiseconds????)',)
fig
