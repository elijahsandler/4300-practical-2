# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv('data_collection.csv')
df.tail()
# Out:
#                      timestamp        ram  database embedding  \
# 7   2025-04-02T17:46:49.153761  16.000000  weaviate     nomic
# 8   2025-04-02T17:48:36.829274  16.000000  weaviate    minilm
# 9   2025-04-02T17:51:38.358285  16.000000  weaviate     mxbai
# 10  2025-04-02T19:00:10.509652  15.279537     redis    minilm
# 11  2025-04-02T19:02:23.299376  15.279537     redis    minilm
#
#                      prompt  response_time_sec  response_length  prompt_length
# 7   tell me about avl trees          21.327975             1335            231
# 8   tell me about avl trees          21.229110             1514            231
# 9   tell me about avl trees          12.979315              738            231
# 10                    hello          27.758860               33            597
# 11  Tell me about AVL trees         100.614640              728           3406

# %%
fig = px.scatter(df, x='prompt_length', y='response_time_sec', color='embedding', symbol='database')
fig.update_layout(xaxis_title='Prompt Length (characters)',
                  yaxis_title='Response Time (seconds)',)
fig
