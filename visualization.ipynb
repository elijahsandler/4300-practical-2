# %%
import plotly.express as px
import pandas as pd

# %%
df = pd.read_csv('data_collection.csv')
df['prompt_length'] = df['prompt'].map(len)
df
# Out:
#                      timestamp database          embedding  \
# 0   2025-04-01T18:22:43.832815    redis  mxbai-embed-large
# 1   2025-04-01T18:23:46.214162    redis  mxbai-embed-large
# 2   2025-04-01T18:24:41.118875    redis  mxbai-embed-large
# 3   2025-04-01T18:25:12.689730    redis  mxbai-embed-large
# 4   2025-04-01T18:25:43.821888    redis  mxbai-embed-large
# 5   2025-04-01T18:27:10.009560    redis              nomic
# 6   2025-04-01T18:27:33.708857    redis              nomic
# 7   2025-04-01T18:28:10.929478    redis              nomic
# 8   2025-04-01T18:28:34.839492    redis              nomic
# 9   2025-04-01T18:28:46.403263    redis              nomic
# 10  2025-04-01T18:29:57.661458    redis             minilm
# 11  2025-04-01T18:30:13.981423    redis             minilm
# 12  2025-04-01T18:31:04.784799    redis             minilm
# 13  2025-04-01T18:31:22.056439    redis             minilm
# 14  2025-04-01T18:31:38.076904    redis             minilm
#
# ...
